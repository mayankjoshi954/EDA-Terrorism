# %% [markdown]
# ## GRIP MAY'21
# ## TASK 4 -> Exploratory Data Analysis - Terrorism
# Dataset -> https://bit.ly/2TK5Xn5

# %%
#impoting required libraries
import pandas as pd

# %% [markdown]
# ## 1. Reading the Data

# %%
df = pd.read_csv("globalterrorismdb_0718dist.csv",encoding='cp1252',low_memory=False)

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
#checking the column names
df.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
# ...

# %%
#changing max column view to 500 so that all columns can be viewed
pd.set_option('display.max_columns', 500)

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region                   region_txt provstate  \
# 0  Dominican Republic       2  Central America & Caribbean       NaN
# 1              Mexico       1                North America   Federal
# 2         Philippines       5               Southeast Asia    Tarlac
# 3              Greece       8               Western Europe    Attica
# 4               Japan       4                    East Asia   Fukouka
#
#             city   latitude   longitude  specificity  vicinity location  \
# ...

# %%
df.isna().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
#changing max row display to 400 so that all rows can be viewed
pd.options.display.max_rows = 400

# %%
#checking the number of null values in each column
df.isna().sum().sort_values(ascending = False)
# Out:
# gsubname3             181671
# weapsubtype4_txt      181621
# weapsubtype4          181621
# weaptype4             181618
# weaptype4_txt         181618
# claimmode3            181558
# claimmode3_txt        181558
# gsubname2             181531
# claim3                181373
# guncertain3           181371
# gname3                181367
# divert                181367
# attacktype3           181263
# attacktype3_txt       181263
# ransomnote            181177
# ransompaidus          181139
# ransomamtus           181128
# claimmode2            181075
# claimmode2_txt        181075
# ransompaid            180917
# corp3                 180665
# targsubtype3          180594
# targsubtype3_txt      180594
# natlty3               180544
# natlty3_txt           180544
# target3               180516
# targtype3_txt         180515
# targtype3             180515
# ransomamt             180341
# weapsubtype3          179998
# weapsubtype3_txt      179998
# weaptype3_txt         179828
# ...

# %% [markdown]
# ## 2. Cleaning the Data

# %%
#dropping those columns which have null values greater than 10000
for x in df.columns:
    if df[x].isna().sum()>10000:
        df.drop(x,axis =1,inplace=True)

# %%
df.isna().sum().sort_values(ascending = False)
# Out:
# longitude          4557
# latitude           4556
# natlty1_txt        1559
# natlty1            1559
# target1             636
# city                434
# provstate           421
# guncertain1         380
# ishostkid           178
# specificity           6
# doubtterr             1
# multiple              1
# vicinity              0
# INT_ANY               0
# crit2                 0
# region_txt            0
# region                0
# country_txt           0
# country               0
# extended              0
# iday                  0
# imonth                0
# iyear                 0
# crit1                 0
# success               0
# crit3                 0
# INT_MISC              0
# suicide               0
# attacktype1           0
# attacktype1_txt       0
# targtype1             0
# targtype1_txt         0
# gname                 0
# individual            0
# weaptype1             0
# weaptype1_txt         0
# property              0
# dbsource              0
# ...

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday  extended  country         country_txt  \
# 0  197000000001   1970       7     2         0       58  Dominican Republic
# 1  197000000002   1970       0     0         0      130              Mexico
# 2  197001000001   1970       1     0         0      160         Philippines
# 3  197001000002   1970       1     0         0       78              Greece
# 4  197001000003   1970       1     0         0      101               Japan
#
#    region                   region_txt provstate           city   latitude  \
# 0       2  Central America & Caribbean       NaN  Santo Domingo  18.456792
# 1       1                North America   Federal    Mexico city  19.371887
# 2       5               Southeast Asia    Tarlac        Unknown  15.478598
# 3       8               Western Europe    Attica         Athens  37.997490
# 4       4                    East Asia   Fukouka        Fukouka  33.580412
#
# ...

# %%
#now check the availabe columns we have
df.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'extended', 'country',
#        'country_txt', 'region', 'region_txt', 'provstate', 'city',
#        'latitude', 'longitude', 'specificity', 'vicinity', 'crit1',
#        'crit2', 'crit3', 'doubtterr', 'multiple', 'success', 'suicide',
#        'attacktype1', 'attacktype1_txt', 'targtype1', 'targtype1_txt',
#        'target1', 'natlty1', 'natlty1_txt', 'gname', 'guncertain1',
#        'individual', 'weaptype1', 'weaptype1_txt', 'property',
#        'ishostkid', 'dbsource', 'INT_LOG', 'INT_IDEO', 'INT_MISC',
#        'INT_ANY'], dtype=object)

# %%
#seelcting columns to remove
to_remove = ['eventid','imonth','iday','extended','country','region','vicinity', 'crit1',
       'crit2', 'crit3', 'doubtterr', 'multiple','specificity','suicide',
       'attacktype1','targtype1','target1', 'natlty1', 'natlty1_txt', 'gname', 'guncertain1',
       'individual', 'weaptype1','property',
       'ishostkid', 'dbsource', 'INT_LOG', 'INT_IDEO', 'INT_MISC',
       'INT_ANY']

# %%
#removing columns which are not required
for i in df.columns:
    if(i in to_remove):
        df.drop(i,axis =1,inplace=True)

# %%
df.head()
# Out:
#    iyear         country_txt                   region_txt provstate  \
# 0   1970  Dominican Republic  Central America & Caribbean       NaN
# 1   1970              Mexico                North America   Federal
# 2   1970         Philippines               Southeast Asia    Tarlac
# 3   1970              Greece               Western Europe    Attica
# 4   1970               Japan                    East Asia   Fukouka
#
#             city   latitude   longitude  success  \
# 0  Santo Domingo  18.456792  -69.951164        1
# 1    Mexico city  19.371887  -99.086624        1
# 2        Unknown  15.478598  120.599741        1
# 3         Athens  37.997490   23.762728        1
# 4        Fukouka  33.580412  130.396361        1
#
#                   attacktype1_txt                targtype1_txt weaptype1_txt
# 0                   Assassination  Private Citizens & Property       Unknown
# 1     Hostage Taking (Kidnapping)      Government (Diplomatic)       Unknown
# ...

# %%
#changing columns names to more readable form
df.columns = ['Year','Country','Region','Province/State','City','Latitude','Longitude','Success','Attack Type','Target Type','Weapon Type']

# %%
df.isna().sum()
# Out:
# Year                 0
# Country              0
# Region               0
# Province/State     421
# City               434
# Latitude          4556
# Longitude         4557
# Success              0
# Attack Type          0
# Target Type          0
# Weapon Type          0
# dtype: int64

# %%
#filling up null values
df['City'] = df['City'].fillna('Unknown')
df['Province/State'] = df['Province/State'].fillna('Unknown')

# %%
df.isna().sum()
# Out:
# Year                 0
# Country              0
# Region               0
# Province/State       0
# City                 0
# Latitude          4556
# Longitude         4557
# Success              0
# Attack Type          0
# Target Type          0
# Weapon Type          0
# dtype: int64

# %% [markdown]
# ## 3. Exploring the Data

# %%
df.tail()
# Out:
#         Year      Country                      Region   Province/State  \
# 181686  2017      Somalia          Sub-Saharan Africa  Middle Shebelle
# 181687  2017        Syria  Middle East & North Africa         Lattakia
# 181688  2017  Philippines              Southeast Asia      Maguindanao
# 181689  2017        India                  South Asia          Manipur
# 181690  2017  Philippines              Southeast Asia      Maguindanao
#
#                  City   Latitude   Longitude  Success  \
# 181686  Ceelka Geelow   2.359673   45.385034        1
# 181687         Jableh  35.407278   35.942679        1
# 181688       Kubentog   6.900742  124.437908        1
# 181689         Imphal  24.798346   93.940430        0
# 181690  Cotabato City   7.209594  124.241966        0
#
#                            Attack Type                  Target Type  \
# 181686                   Armed Assault                     Military
# 181687               Bombing/Explosion                     Military
# ...

# %%
df.describe()
# Out:
#                 Year       Latitude     Longitude        Success
# count  181691.000000  177135.000000  1.771340e+05  181691.000000
# mean     2002.638997      23.498343 -4.586957e+02       0.889598
# std        13.259430      18.569242  2.047790e+05       0.313391
# min      1970.000000     -53.154613 -8.618590e+07       0.000000
# 25%      1991.000000      11.510046  4.545640e+00       1.000000
# 50%      2009.000000      31.467463  4.324651e+01       1.000000
# 75%      2014.000000      34.685087  6.871033e+01       1.000000
# max      2017.000000      74.633553  1.793667e+02       1.000000

# %%
df['Attack Type'].unique()
# Out:
# array(['Assassination', 'Hostage Taking (Kidnapping)',
#        'Bombing/Explosion', 'Facility/Infrastructure Attack',
#        'Armed Assault', 'Hijacking', 'Unknown', 'Unarmed Assault',
#        'Hostage Taking (Barricade Incident)'], dtype=object)

# %%
df['Target Type'].unique()
# Out:
# array(['Private Citizens & Property', 'Government (Diplomatic)',
#        'Journalists & Media', 'Police', 'Utilities', 'Military',
#        'Government (General)', 'Airports & Aircraft', 'Business',
#        'Educational Institution', 'Violent Political Party',
#        'Religious Figures/Institutions', 'Unknown', 'Transportation',
#        'Tourists', 'NGO', 'Telecommunication', 'Food or Water Supply',
#        'Terrorists/Non-State Militia', 'Other', 'Maritime',
#        'Abortion Related'], dtype=object)

# %%
df['Weapon Type'].unique()
# Out:
# array(['Unknown', 'Explosives', 'Incendiary', 'Firearms', 'Chemical',
#        'Melee', 'Sabotage Equipment',
#        'Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)',
#        'Fake Weapons', 'Radiological', 'Other', 'Biological'],
#       dtype=object)

# %% [markdown]
# ## 4. Exporting cleaned data for visualization

# %%
df.to_csv('cleaned_data_terrorist.csv',index=False,header=True)

# %% [markdown]
# ## Tableau viz link :
# https://public.tableau.com/profile/mayankjoshi954#!/vizhome/TerroristAttacks1970-2017_16210967252220/Dashboard1
